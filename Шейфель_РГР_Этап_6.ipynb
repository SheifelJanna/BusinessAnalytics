# %% [markdown]
# ***Шейфель Ж.В ПИ-321***
#
# > ***Номер зачётки 19130168***

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
reg = linear_model.LinearRegression()
np.random.seed(19130168)
A = []
B = []
T = []
N = 10000
n = 1000

# %%
for i in range(n):
  t = time.time()
  x = np.random.uniform(low=150, high=200, size=N)
  e  = np.random.normal(loc=0, scale=10, size=N)
  y = -100 + x + e
  reg.fit(x.reshape(-1,1), y.reshape (-1, 1))
  A.append (reg.intercept_[0])
  B.append(reg.coef_[0][0])
  T.append(time.time() - t)

# %%
plt.figure(figsize=(10,6))
plt.hist(B, bins = 20, edgecolor = 'black', color='white')
plt.title('Histogram of B estimates')
plt.show()

# %%
min(T), np.median(T), max(T)
# Out:
# (0.00029850006103515625, 0.00035130977630615234, 0.0011644363403320312)

# %%
#ПоМетодичке
plt.figure(figsize=(10,4)) 
plt.plot(T, marker=".")
plt.show()

# %%
#Эксперимент
plt.figure(figsize=(10,4))
plt.plot(T[75:100], marker=".")
plt.show()

# %%
#ПоМетодичке
plt.figure(figsize=(10,4))
plt.plot(T[300:500], marker=".")
plt.show()

# %%
#Эксперимент
plt.figure(figsize=(10,4))
plt.plot(T[80:100], marker=".")
plt.show()

# %%
#ПоМетодичке
plt.figure(figsize=(10,4))
plt.hist(T[300:500], bins=30,edgecolor='black', color = 'white')
plt.show()

# %%
#Эксперимент
plt.figure(figsize=(10,4))
plt.hist(T[70:100], bins=30,edgecolor='black', color = 'white')
plt.show()

# %%
#ПоМетодичке
plt.figure(figsize=(10,4))
plt.plot(T, marker=".")
plt.show()

# %%
#Эксперимент
plt.figure(figsize=(10,4))
plt.plot(T[85:100], marker=".")
plt.show()

# %%
#ПоМетодичке
plt.figure(figsize=(10,4))
plt.plot(T[105:195], marker=".")
plt.show()

# %%
#ПоЭксперимент
plt.figure(figsize=(10,4))
plt.plot(T[76:100], marker=".")
plt.show()

# %%
#ПоМетодичке
plt.figure(figsize=(10,4))
plt.hist(T[105:195], bins=30,edgecolor='black', color = 'white')
plt.show()

# %%
#Эксперимент
plt.figure(figsize=(10,4))
plt.hist(T[105:200], bins=30,edgecolor='black', color = 'white')
plt.show()
